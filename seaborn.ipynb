# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset["salary"].fillna(0,inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()

# %%
dataset.shape

# %%
dataset.shape[0]

# %% [markdown]
# # univariete graph

# %%
sb.distplot(dataset['ssc_p'],hist=True,kde=True,kde_kws={'color':'red'})

# %% [markdown]
# # bivarite graph

# %%
sb.jointplot(x='ssc_p',y='salary',data=dataset)
plt.show()

# %%
sb.jointplot(x='hsc_p',y='salary',data=dataset)
plt.show()

# %%
#this is also called scatter plot

# %%
sb.jointplot(x='degree_p',y='salary',data=dataset)
plot.show()

# %%
sb.violinplot(x='specialisation',y='salary',data=dataset)
Plot.show()

# %%
sb.violinplot(x='specialisation',y='salary',hue='gender',data=dataset)
Plot.show()

# %%
sb.boxplot(x='ssc_b',y='ssc_p',data=dataset)
plt.show()

# %%
sb.boxplot(x='ssc_b',y='ssc_p',data=dataset,hue='gender')
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset('exercise')
sb.factorplot(x= "time",y="pulse",hue="kind",kind='violin',col="diet",data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9076\1283002146.py in <module>
#       3 from matplotlib import pyplot as plt
#       4 df=sb.load_dataset('exercise')
# ----> 5 sb.factorplot(x= "time",y="pulse",hue="kind",kind='violin',col="diet",data=df)
#       6 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'
